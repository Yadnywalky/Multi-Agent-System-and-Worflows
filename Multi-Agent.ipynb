# %% [markdown]
# # Multi-Agent Systems & Workflow Patterns

# %% [markdown]
# ## Section 1: Setup

# %%
import os
from kaggle_secrets import UserSecretsClient

try:
    GOOGLE_API_KEY = UserSecretsClient().get_secret("GOOGLE_API_KEY")
    os.environ["GOOGLE_API_KEY"] = GOOGLE_API_KEY
    print("✅ Gemini API key setup complete.")
except Exception as e:
    print(
        f"🔑 Authentication Error: Please make sure you have added 'GOOGLE_API_KEY' to your Kaggle secrets. Details: {e}"
    )
# Out:
# ✅ Gemini API key setup complete.

# %% [markdown]
# ### Import ADK components
#
# Now, import the specific components you'll need from the Agent Development Kit and the Generative AI library. This keeps your code organized and ensures we have access to the necessary building blocks.

# %%
from google.adk.agents import Agent, SequentialAgent, ParallelAgent, LoopAgent
from google.adk.models.google_llm import Gemini
from google.adk.runners import InMemoryRunner
from google.adk.tools import AgentTool, FunctionTool, google_search
from google.genai import types

print("ADK components imported successfully.")
# Out:
# ADK components imported successfully.

# %% [markdown]
# ### Configure Retry Options
#
# When working with LLMs, you may encounter transient errors like rate limits or temporary service unavailability. Retry options automatically handle these failures by retrying the request with exponential backoff.

# %%
retry_config=types.HttpRetryOptions(
    attempts=5,  # Maximum retry attempts
    exp_base=7,  # Delay multiplier
    initial_delay=1,
    http_status_codes=[429, 500, 503, 504], # Retry on these HTTP errors
)

# %% [markdown]
# **Architecture: Single Agent vs Multi-Agent Team**
#
# <!--
# ```mermaid
# graph TD
#     subgraph Single["❌ Monolithic Agent"]
#         A["One Agent Does Everything"]
#     end
#
#     subgraph Multi["✅ Multi-Agent Team"]
#         B["Root Coordinator"] -- > C["Research Specialist"]
#         B -- > E["Summary Specialist"]
#
#         C -- >|findings| F["Shared State"]
#         E -- >|summary| F
#     end
#
#     style A fill:#ffcccc
#     style B fill:#ccffcc
#     style F fill:#ffffcc
# ```
# -->

# %% [markdown]
# <img width="800" src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day1/multi-agent-team.png" alt="Multi-agent Team" />

# %% [markdown]
# ### Example: Research & Summarization System
#
# Let's build a system with two specialized agents:
#
# 1. **Research Agent** - Searches for information using Google Search
# 2. **Summarizer Agent** - Creates concise summaries from research findings

# %%
# Research Agent: Its job is to use the google_search tool and present findings.
research_agent = Agent(
    name="ResearchAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a specialized research agent. Your only job is to use the
    google_search tool to find 2-3 pieces of relevant information on the given topic and present the findings with citations.""",
    tools=[google_search],
    output_key="research_findings",  # The result of this agent will be stored in the session state with this key.
)

print("Research_Agent Created.")
# Out:
# Research_Agent Created.

# %%
# Summarizer Agent: Its job is to summarize the text it receives.
summarizer_agent = Agent(
    name="SummarizerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The instruction is modified to request a bulleted list for a clear output format.
    instruction="""Read the provided research findings: {research_findings}
Create a concise summary as a bulleted list with 3-5 key points.""",
    output_key="final_summary",
)

print("Summarizer_Agent Created.")
# Out:
# Summarizer_Agent Created.

# %%
# Root Coordinator: Orchestrates the workflow by calling the sub-agents as tools.
root_agent = Agent(
    name="ResearchCoordinator",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This instruction tells the root agent HOW to use its tools (which are the other agents).
    instruction="""You are a research coordinator. Your goal is to answer the user's query by orchestrating a workflow.
1. First, you MUST call the `ResearchAgent` tool to find relevant information on the topic provided by the user.
2. Next, after receiving the research findings, you MUST call the `SummarizerAgent` tool to create a concise summary.
3. Finally, present the final summary clearly to the user as your response.""",
    # We wrap the sub-agents in `AgentTool` to make them callable tools for the root agent.
    tools=[AgentTool(research_agent), AgentTool(summarizer_agent)],
)

print("Root_Agent Created.")
# Out:
# Root_Agent Created.

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "What are the latest advancements in quantum computing and what do they mean for AI?"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > What are the latest advancements in quantum computing and what do they mean for AI?
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# ResearchCoordinator > Quantum computing advancements are set to revolutionize AI by overcoming current computational limits and enabling new capabilities. Key developments include enhanced computational power through parallel processing, leading to improved machine learning algorithms and the ability to solve previously intractable complex problems. Progress in error correction is crucial for stability, and while widespread commercial adoption is still likely over a decade away, the field is moving towards hybrid quantum-classical systems that leverage the strengths of both. This integration promises more efficient and powerful AI solutions in the future.

# %%
print("You've just Built your first Multi-Agent System!")
# Out:
# You've just Built your first Multi-Agent System!

# %% [markdown]
# ---
#
# ## Section 3: Sequential Workflows - The Assembly Line
#
# **`SequentialAgent`** acts like an assembly line, running each sub-agent in the exact order you list them. The output of one agent automatically becomes the input for the next, creating a predictable and reliable workflow.
#
# **Architecture: Blog Post Creation Pipeline**
#
# <!--
# ```mermaid
# graph LR
#     A["User Input: Blog about AI"] -- > B["Outline Agent"]
#     B -- >|blog_outline| C["Writer Agent"]
#     C -- >|blog_draft| D["Editor Agent"]
#     D -- >|final_blog| E["Output"]
#
#     style B fill:#ffcccc
#     style C fill:#ccffcc
#     style D fill:#ccccff
# ```
# -->

# %% [markdown]
# <img width="1000" src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day1/sequential-agent.png" alt="Sequential Agent" />

# %% [markdown]
# ### Example: Blog Post Creation with Sequential Agents
#
# Let's build a system with three specialized agents:
#
# 1. **Outline Agent** - Creates a blog outline for a given topic
# 2. **Writer Agent** - Writes a blog post
# 3. **Editor Agent** - Edits a blog post draft for clarity and structure

# %%
# Outline Agent: Creates the initial blog post outline.
outline_agent = Agent(
    name="OutlineAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Create a blog outline for the given topic with:
    1. A catchy headline
    2. An introduction hook
    3. 3-5 main sections with 2-3 bullet points for each
    4. A concluding thought""",
    output_key="blog_outline",  # The result of this agent will be stored in the session state with this key.
)

print("Outline_Agent Created.")
# Out:
# Outline_Agent Created.

# %%
# Writer Agent: Writes the full blog post based on the outline from the previous agent.
writer_agent = Agent(
    name="WriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # The `{blog_outline}` placeholder automatically injects the state value from the previous agent's output.
    instruction="""Following this outline strictly: {blog_outline}
    Write a brief, 200 to 300-word blog post with an engaging and informative tone.""",
    output_key="blog_draft",  # The result of this agent will be stored with this key.
)

print("Writer_Agent Created.")
# Out:
# Writer_Agent Created.

# %%
# Editor Agent: Edits and polishes the draft from the writer agent.
editor_agent = Agent(
    name="EditorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # This agent receives the `{blog_draft}` from the writer agent's output.
    instruction="""Edit this draft: {blog_draft}
    Your task is to polish the text by fixing any grammatical errors, improving the flow and sentence structure, and enhancing overall clarity.""",
    output_key="final_blog",  # This is the final output of the entire pipeline.
)

print("Editor_Agent Created.")
# Out:
# Editor_Agent Created.

# %% [markdown]
# Then we bring the agents together under a sequential agent, which runs the agents in the order that they are listed:

# %%
root_agent = SequentialAgent(
    name="BlogPipeline",
    sub_agents=[outline_agent, writer_agent, editor_agent],
)

print("Sequential Agent Created.")
# Out:
# Sequential Agent Created.

# %% [markdown]
# Let's run the agent and give it a topic to write a blog post about:

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a blog post about the benefits of multi-agent systems for software developers"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a blog post about the benefits of multi-agent systems for software developers
# OutlineAgent > ## Multi-Agent Systems: Your New Software Development Superpower
#
# **Introduction Hook:** Ever feel like your software projects are juggling too many balls? Imagine a team of tireless, intelligent assistants, each an expert in a specific task, collaborating seamlessly to build something amazing. That's the promise of Multi-Agent Systems (MAS), and for software developers, it's not science fiction – it's a powerful new toolkit ready to revolutionize how you build.
#
# ---
#
# ### Section 1: The Power of Specialization - Breaking Down Complexity
#
# *   **Task Decomposition:** MAS allows you to break down complex software requirements into smaller, manageable tasks, each handled by a specialized agent. This makes development less overwhelming and promotes modularity.
# *   **Expertise Embodiment:** Agents can be designed to embody specific expertise, whether it's data validation, UI generation, API integration, or even security testing. This ensures optimal performance and accuracy in each component.
# *   **Parallel Processing:** Unlike traditional monolithic architectures, MAS naturally lends itself to parallel execution. Different agents can work on their assigned tasks simultaneously, significantly speeding up development and runtime.
#
# ### Section 2: Enhanced Collaboration and Communication
#
# *   **Inter-Agent Communication:** MAS provides frameworks for agents to communicate and coordinate their actions. This can be through message passing, shared knowledge bases, or direct interaction protocols, enabling intelligent coordination.
# *   **Decentralized Decision-Making:** In complex scenarios, agents can make local decisions based on their individual knowledge and goals, contributing to a more robust and resilient overall system. This avoids single points of failure.
# *   **Dynamic Adaptation:** Agents can dynamically adapt their behavior and strategies based on the actions of other agents and environmental changes, leading to more flexible and responsive software.
#
# ### Section 3: Solving Real-World Problems with MAS
#
# *   **Complex System Simulation:** MAS is ideal for simulating complex real-world systems, such as traffic flow, financial markets, or biological processes, allowing developers to test and optimize solutions before deployment.
# *   **Intelligent Automation:** From automating repetitive coding tasks to building sophisticated intelligent assistants for end-users, MAS opens doors to unprecedented levels of automation.
# *   **Distributed Systems and IoT:** The inherent distributed nature of MAS makes it a perfect fit for developing applications in the Internet of Things (IoT) and other distributed computing environments.
#
# ### Section 4: The Developer's Advantage - Why You Should Care
#
# *   **Reduced Development Time & Cost:** By leveraging specialized agents and parallel processing, MAS can significantly shorten development cycles and reduce overall project costs.
# *   **Increased Software Robustness & Scalability:** Modular design and decentralized control lead to more resilient and scalable software that can handle increasing loads and adapt to changing requirements.
# *   **Innovation and New Possibilities:** MAS empowers developers to tackle problems previously considered too complex or computationally intensive, paving the way for innovative new software solutions.
#
# ---
#
# **Concluding Thought:** Multi-Agent Systems are no longer a niche academic concept. They are a powerful paradigm shift offering tangible benefits for software developers. By embracing the principles of intelligent collaboration and distributed expertise, you can unlock a new level of efficiency, innovation, and problem-solving capability in your projects. It's time to harness the superpower of MAS and build the future of software, smarter and faster.
# WriterAgent > ## Multi-Agent Systems: Your New Software Development Superpower
#
# Ever feel like your software projects are juggling too many balls? Imagine a team of tireless, intelligent assistants, each an expert in a specific task, collaborating seamlessly to build something amazing. That's the promise of Multi-Agent Systems (MAS), and for software developers, it's not science fiction – it's a powerful new toolkit ready to revolutionize how you build.
#
# MAS empowers you to break down complex problems into manageable tasks, assigning each to specialized agents. Think of agents embodying expertise in data validation, UI generation, or even security testing. This specialization leads to unparalleled modularity and optimal performance. Crucially, MAS enables parallel processing; different agents can tackle their assignments concurrently, dramatically speeding up both development and runtime.
#
# Beyond task execution, MAS fosters intelligent collaboration. Agents communicate and coordinate through sophisticated frameworks, allowing for decentralized decision-making. This distributed approach enhances system robustness and resilience, avoiding single points of failure. Furthermore, agents can dynamically adapt their strategies based on interactions and environmental changes, creating more flexible and responsive software.
#
# The advantages for developers are clear: reduced development time and costs, increased software robustness, and enhanced scalability. MAS opens doors to simulating complex systems, automating intricate tasks, and building sophisticated distributed applications for IoT environments. It’s time to embrace this powerful paradigm shift and unlock a new level of efficiency and innovation in your projects. Harness the superpower of MAS and build the future of software, smarter and faster.
# EditorAgent > ## Multi-Agent Systems: Supercharge Your Software Development
#
# Are your software projects feeling like a juggling act with too many moving parts? Imagine a team of highly skilled, tireless digital assistants, each a master of their craft, working together in perfect harmony to bring your vision to life. This isn't a scene from a futuristic movie; this is the reality of Multi-Agent Systems (MAS), and for software developers, it represents a revolutionary new approach to building software.
#
# MAS offers a powerful way to dissect complex challenges into manageable units. You can break down large projects into smaller, distinct tasks, assigning each to a specialized "agent." Think of these agents as dedicated experts: one might excel at data validation, another at generating user interfaces, and a third at performing rigorous security testing. This division of labor not only makes development more straightforward but also leads to significant improvements in modularity and overall system performance. A key advantage here is **parallel processing**: multiple agents can execute their assigned tasks simultaneously, drastically accelerating both the development cycle and the final application's runtime.
#
# But MAS goes beyond simple task delegation. It cultivates **intelligent collaboration**. Agents can communicate and coordinate their efforts through advanced frameworks, enabling sophisticated teamwork and decentralized decision-making. This distributed architecture inherently boosts system **robustness and resilience**, effectively eliminating single points of failure. Moreover, agents possess the capability to **dynamically adapt** their strategies in response to interactions with other agents and evolving environmental conditions, resulting in software that is exceptionally flexible and responsive.
#
# For software developers, the benefits are compelling: **reduced development time and costs**, **increased software reliability**, and **enhanced scalability**. MAS unlocks new possibilities, from simulating intricate real-world systems and automating complex workflows to building sophisticated distributed applications for the Internet of Things (IoT). It's time to embrace this transformative paradigm. By harnessing the power of MAS, you can unlock unprecedented levels of efficiency and innovation, building the future of software – smarter and faster.

# %%
print("Great Job!!, You have created a Sequential Agent.")
print("\nThis is perfect for tasks that build on each other, but slow if the task are independent.")
# Out:
# Great Job!!, You have created a Sequential Agent.
#
# This is perfect for tasks that build on each other, but slow if the task are independent.

# %% [markdown]
# ---
# ## Section 4: Parallel Workflows
#
# **`ParallelAgent`** agent executes all of its sub-agents concurrently, dramatically speeding up the workflow. Once all parallel tasks are complete, you can then pass their combined results to a final 'aggregator' step.
#
# **Architecture: Multi-Topic Research**
#
# <!--
# ```mermaid
# graph TD
#     A["User Request: Research 3 topics"] -- > B["Parallel Execution"]
#     B -- > C["Tech Researcher"]
#     B -- > D["Health Researcher"]
#     B -- > E["Finance Researcher"]
#
#     C -- > F["Aggregator"]
#     D -- > F
#     E -- > F
#     F -- > G["Combined Report"]
#
#     style B fill:#ffffcc
#     style F fill:#ffccff
# ```
# -->

# %% [markdown]
# <img width="600" src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day1/parallel-agent.png" alt="Parallel Agent" />

# %% [markdown]
# ### Example: Parallel Multi-Topic Research
#
# Let's build a system with four agents:
#
# 1. **Tech Researcher** - Researches AI/ML news and trends
# 2. **Health Researcher** - Researches recent medical news and trends
# 3. **Finance Researcher** - Researches finance and fintech news and trends
# 4. **Aggregator Agent** - Combines all research findings into a single summary

# %%
# Tech Researcher: Focuses on AI and ML trends.
tech_researcher = Agent(
    name="TechResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research the latest AI/ML trends. Include 3 key developments,
the main companies involved, and the potential impact. Keep the report very concise (100 words).""",
    tools=[google_search],
    output_key="tech_research",  # The result of this agent will be stored in the session state with this key.
)

print("Tech_Researcher Created.")
# Out:
# Tech_Researcher Created.

# %%
# Health Researcher: Focuses on medical breakthroughs.
health_researcher = Agent(
    name="HealthResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research recent medical breakthroughs. Include 3 significant advances,
their practical applications, and estimated timelines. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="health_research",  # The result will be stored with this key.
)

print("Health_Researcher Created.")
# Out:
# Health_Researcher Created.

# %%
# Finance Researcher: Focuses on fintech trends.
finance_researcher = Agent(
    name="FinanceResearcher",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Research current fintech trends. Include 3 key trends,
their market implications, and the future outlook. Keep the report concise (100 words).""",
    tools=[google_search],
    output_key="finance_research",  # The result will be stored with this key.
)

print("Finance_Researcher Created.")
# Out:
# Finance_Researcher Created.

# %%
# The AggregatorAgent runs *after* the parallel step to synthesize the results.
aggregator_agent = Agent(
    name="AggregatorAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    # It uses placeholders to inject the outputs from the parallel agents, which are now in the session state.
    instruction="""Combine these three research findings into a single executive summary:

    **Technology Trends:**
    {tech_research}
    
    **Health Breakthroughs:**
    {health_research}
    
    **Finance Innovations:**
    {finance_research}
    
    Your summary should highlight common themes, surprising connections, and the most important key takeaways from all three reports. The final summary should be around 200 words.""",
    output_key="executive_summary",  # This will be the final output of the entire system.
)

print("Aggregator_Agent Created.")
# Out:
# Aggregator_Agent Created.

# %% [markdown]
# Then we bring the agents together under a parallel agent, which is itself nested inside of a sequential agent.

# %%
# The ParallelAgent runs all its sub-agents simultaneously.
parallel_research_team = ParallelAgent(
    name="ParallelResearchTeam",
    sub_agents=[tech_researcher, health_researcher, finance_researcher],
)

# This SequentialAgent defines the high-level workflow: run the parallel team first, then run the aggregator.
root_agent = SequentialAgent(
    name="ResearchSystem",
    sub_agents=[parallel_research_team, aggregator_agent],
)

print("Parallel and Sequential Agents Created.")
# Out:
# Parallel and Sequential Agents Created.

# %% [markdown]
# Let's run the agent and give it a prompt to research the given topics:

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Run the daily executive briefing on Tech, Health, and Finance"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Run the daily executive briefing on Tech, Health, and Finance
# HealthResearcher > **Health:** mRNA vaccine technology, initially developed for COVID-19, is now being explored for numerous other diseases. Vaccine microneedle patches and dual-insecticide bed nets are also showing promise for wider global health applications. AI is revolutionizing diagnostics and treatment plans, with projections indicating a significant market increase.
#
# **Technology:** Artificial intelligence (AI) adoption has accelerated rapidly, surpassing the internet's growth curve. Agentic AI, capable of autonomous planning and execution of workflows, is a new frontier. 5G connectivity continues to enable advancements in autonomous vehicles and smart cities.
#
# **Finance:** AI and machine learning are personalizing financial planning and risk assessment. Digital assets like crypto and stablecoins are reshaping payments, with ongoing exploration of central bank digital currencies. Practical applications of generative AI are emerging in budgeting and investment portfolio management. These trends suggest a continued integration of technology into financial services, with an estimated 10-20 year timeline for widespread transformation in some areas.
# TechResearcher > **Key AI/ML Trends in 2025:**
#
# 1.  **Generative AI and Multimodal Expansion:** Generative AI is moving beyond text, encompassing image, video, and audio creation. Major companies like Google (Gemini, Imagen) and OpenAI are leading this charge, with tools that understand and generate content across various data types. This trend promises to revolutionize creative industries and content generation.
#
# 2.  **Agentic AI:** The development of AI agents capable of independent action is a significant frontier. These systems, like Salesforce's Agentforce, can autonomously manage tasks and workflows. While still in early stages, they hold potential for automating complex tasks across various sectors.
#
# 3.  **AI-Powered Data Analytics & MLOps:** AI is transforming data management, from collection to insight generation. Platforms like Google Cloud's Vertex AI offer end-to-end ML lifecycle support. MLOps (Machine Learning Operations) is crucial for managing the entire ML model lifecycle, ensuring efficiency and cost-effectiveness in deployment and maintenance.
#
# **Main Companies Involved:**
#
# *   **Google:** Leading with multimodal models like Gemini and platforms like Vertex AI.
# *   **OpenAI:** Known for advanced generative models such as ChatGPT and Sora.
# *   **Microsoft:** Developing tools like Copilot for various applications and offering AI through Azure.
# *   **NVIDIA:** Providing the crucial GPU hardware and software solutions powering AI advancements.
# *   **Salesforce:** Innovating with agentic AI through platforms like Agentforce.
#
# **Potential Impact:**
#
# These trends are set to significantly impact business strategies and operations. Generative AI will transform content creation and personalization. Agentic AI will drive automation and efficiency. AI-powered analytics and MLOps will streamline data-driven decision-making and accelerate AI adoption. The overall economic impact is substantial, with projections suggesting significant GDP growth driven by AI and ML development.
# FinanceResearcher > **Tech Trends Briefing:**
#
# **1. AI Agents & Generative AI:** AI is no longer just analytical; it's becoming agentic, capable of planning and executing tasks autonomously. This impacts all sectors by creating "virtual coworkers" and automating complex workflows.
#
# *   **Market Implications:** Increased efficiency, new product/service development, and a shift in workforce needs towards AI oversight and collaboration.
# *   **Future Outlook:** Pervasive integration into all aspects of technology and business, driving innovation and demanding new governance and ethical frameworks.
#
# **2. Spatial Computing:** Interacting with virtual objects in physical spaces, driven by augmented reality, offers immersive user experiences.
#
# *   **Market Implications:** Growth in AR/VR hardware and software, new forms of entertainment, training, and remote collaboration.
# *   **Future Outlook:** Becoming a standard interface for many digital interactions, blurring the lines between physical and digital realities.
#
# **3. Application-Specific Semiconductors:** The demand for AI and advanced computing is spurring innovation in specialized chips for efficiency and performance.
#
# *   **Market Implications:** Growth in the semiconductor industry, customized hardware solutions for AI, and potential for new performance benchmarks.
# *   **Future Outlook:** Essential infrastructure for advanced AI and computing, driving breakthroughs in speed and energy efficiency.
#
# ---
#
# **Health Trends Briefing:**
#
# **1. Personalized Nutrition & Biohacking:** A move towards highly tailored dietary plans and proactive health optimization using data and advanced supplements.
#
# *   **Market Implications:** Growth in personalized nutrition services, genetic testing, functional foods, and biohacking tools.
# *   **Future Outlook:** Health management becomes increasingly individualized and preventative, focusing on maximizing "healthspan" rather than just lifespan.
#
# **2. Digital & Mental Health Integration:** Teletherapy, AI mental health bots, and VR are making mental health support more accessible and destigmatized.
#
# *   **Market Implications:** Expansion of digital health platforms, new therapeutic modalities, and increased demand for mental wellness solutions.
# *   **Future Outlook:** Mental healthcare becomes seamlessly integrated into digital life, offering proactive and accessible support.
#
# **3. Genomics and Preventive Healthcare:** Utilizing genetic information to shift from treating illness to preventing it and personalizing treatments.
#
# *   **Market Implications:** Increased demand for genetic testing, precision medicine, and preventative health services.
# *   **Future Outlook:** Healthcare becomes predictive and personalized, with genetic insights guiding health decisions from early life.
#
# ---
#
# **Finance Trends Briefing:**
#
# **1. AI in Finance:** AI and generative AI are automating tasks like bookkeeping, forecasting, and fraud detection, while also transforming cybersecurity.
#
# *   **Market Implications:** Increased operational efficiency, enhanced risk management, and new challenges in cybersecurity.
# *   **Future Outlook:** AI becomes an indispensable tool for financial decision-making, automation, and security.
#
# **2. Real-Time Data & Transparency:** The shift towards instant financial data enables faster decision-making and greater transparency for stakeholders.
#
# *   **Market Implications:** Improved agility in financial operations, enhanced investor relations, and demand for robust data infrastructure.
# *   **Future Outlook:** Real-time financial insights become the norm, driving proactive management and greater accountability.
#
# **3. Asset-Backed Finance & Private Credit Growth:** Asset-backed finance is gaining traction for its risk diversification, and private credit is a strategic growth area for institutions.
#
# *   **Market Implications:** Increased investment in alternative assets, evolving role of traditional banks, and growth in non-bank financial institutions.
# *   **Future Outlook:** Diversification of funding sources and evolving competitive landscape for traditional financial institutions.
# AggregatorAgent > Here's a combined executive summary:
#
# **Executive Briefing: Tech, Health, and Finance Convergence Driven by AI**
#
# Artificial Intelligence (AI) is the dominant, cross-sectoral force, rapidly transforming technology, health, and finance. Generative AI and multimodal capabilities are revolutionizing content creation and personalization, while the emergence of agentic AI signifies a significant leap towards autonomous task execution and workflow automation, creating "virtual coworkers."
#
# In healthcare, AI is revolutionizing diagnostics, treatment plans, and personalized medicine, with advancements like mRNA technology and genomics further enabling preventive and tailored health strategies. This mirrors finance, where AI is personalizing financial planning, risk assessment, and automating tasks from bookkeeping to fraud detection, all while digital assets and real-time data reshape payment systems and investment management.
#
# The pervasive integration of AI necessitates advancements in specialized semiconductors for performance and efficiency. The overarching trend points to a future where AI drives unprecedented efficiency, innovation, and personalized experiences across all industries, while also demanding new governance and ethical frameworks.

# %%
print ("Great!, You have created Parallel Agent Workflow that can dramatically speed up workflows by running independent taks concurrently")
# Out:
# Great!, You have created Parallel Agent Workflow that can dramatically speed up workflows by running independent taks concurrently

# %% [markdown]
# ---
# ## Section 5: Loop Workflows
#
# A `LoopAgent` runs a set of sub-agents repeatedly *until a specific condition is met or a maximum number of iterations is reached.* This creates a refinement cycle, allowing the agent system to improve its own work over and over.
#
# **Architecture: Story Writing & Critique Loop**
#
# <!--
# ```mermaid
# graph TD
#     A["Initial Prompt"] -- > B["Writer Agent"]
#     B -- >|story| C["Critic Agent"]
#     C -- >|critique| D{"Iteration < Max<br>AND<br>Not Approved?"}
#     D -- >|Yes| B
#     D -- >|No| E["Final Story"]
#
#     style B fill:#ccffcc
#     style C fill:#ffcccc
#     style D fill:#ffffcc
# ```
# -->

# %% [markdown]
# <img width="250" src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day1/loop-agent.png" alt="Loop Agent" />

# %% [markdown]
# ### Example: Iterative Story Refinement
#
# Let's build a system with two agents:
#
# 1. **Writer Agent** - Writes a draft of a short story
# 2. **Critic Agent** - Reviews and critiques the short story to suggest improvements

# %%
# This agent runs ONCE at the beginning to create the first draft.
initial_writer_agent = Agent(
    name="InitialWriterAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""Based on the user's prompt, write the first draft of a short story (around 100-150 words).
    Output only the story text, with no introduction or explanation.""",
    output_key="current_story",  # Stores the first draft in the state.
)

print("Initial_Writer_Agent Created.")
# Out:
# Initial_Writer_Agent Created.

# %%
# This agent's only job is to provide feedback or the approval signal. It has no tools.
critic_agent = Agent(
    name="CriticAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a constructive story critic. Review the story provided below.
    Story: {current_story}
    
    Evaluate the story's plot, characters, and pacing.
    - If the story is well-written and complete, you MUST respond with the exact phrase: "APPROVED"
    - Otherwise, provide 2-3 specific, actionable suggestions for improvement.""",
    output_key="critique",  # Stores the feedback in the state.
)

print("Critic_Agent Created.")
# Out:
# Critic_Agent Created.

# %% [markdown]
# Now, we need a way for the loop to actually stop based on the critic's feedback. The `LoopAgent` itself doesn't automatically know that "APPROVED" means "stop."
#
# We need an agent to give it an explicit signal to terminate the loop.
#
# We do this in two parts:
#
# 1. A simple Python function that the `LoopAgent` understands as an "exit" signal.
# 2. An agent that can call that function when the right condition is met.
#
# First, you'll define the `exit_loop` function:

# %%
# This is the function that the RefinerAgent will call to exit the loop.
def exit_loop():
    """Call this function ONLY when the critique is 'APPROVED', indicating the story is finished and no more changes are needed."""
    return {"status": "approved", "message": "Story approved. Exiting refinement loop."}


print("Exit_loop function created.")
# Out:
# Exit_loop function created.

# %% [markdown]
# To let an agent call this Python function, we wrap it in a `FunctionTool`. Then, we create a `RefinerAgent` that has this tool.

# %%
# This agent refines the story based on critique OR calls the exit_loop function.
refiner_agent = Agent(
    name="RefinerAgent",
    model=Gemini(
        model="gemini-2.5-flash-lite",
        retry_options=retry_config
    ),
    instruction="""You are a story refiner. You have a story draft and critique.
    
    Story Draft: {current_story}
    Critique: {critique}
    
    Your task is to analyze the critique.
    - IF the critique is EXACTLY "APPROVED", you MUST call the `exit_loop` function and nothing else.
    - OTHERWISE, rewrite the story draft to fully incorporate the feedback from the critique.""",
    output_key="current_story",  # It overwrites the story with the new, refined version.
    tools=[
        FunctionTool(exit_loop)
    ],  # The tool is now correctly initialized with the function reference.
)

print("Refiner_Agent Created.")
# Out:
# Refiner_Agent Created.

# %% [markdown]
# Then we bring the agents together under a loop agent, which is itself nested inside of a sequential agent.

# %%
# The LoopAgent contains the agents that will run repeatedly: Critic -> Refiner.
story_refinement_loop = LoopAgent(
    name="StoryRefinementLoop",
    sub_agents=[critic_agent, refiner_agent],
    max_iterations=2,  # Prevents infinite loops
)

# The root agent is a SequentialAgent that defines the overall workflow: Initial Write -> Refinement Loop.
root_agent = SequentialAgent(
    name="StoryPipeline",
    sub_agents=[initial_writer_agent, story_refinement_loop],
)

print("Loop and Sequential Agents Created.")
# Out:
# Loop and Sequential Agents Created.

# %% [markdown]
# Let's run the agent and give it a topic to write a short story about:

# %%
runner = InMemoryRunner(agent=root_agent)
response = await runner.run_debug(
    "Write a short story about a lighthouse keeper who discovers a mysterious, glowing map"
)
# Out:
#  ### Created new session: debug_session_id
#
# User > Write a short story about a lighthouse keeper who discovers a mysterious, glowing map
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# InitialWriterAgent > Elias traced the salt-worn lines on the worn chart. It was a relic, tucked away in a forgotten sea chest, unlike any he’d seen in his fifty years tending the Porthaven light. This one, however, pulsed with an inner luminescence, faint emerald lines weaving a path across familiar seas, yet veering off into uncharted depths. He held it closer. The glow intensified, casting an eerie light on his weathered face. A single, pulsing X marked a spot far beyond the edge of any known land. Elias shivered, not from the sea spray, but from a thrill he hadn't felt since he was a boy, dreaming of distant shores. The map hummed, a silent promise of adventure.
# CriticAgent > The story presents a compelling hook with the discovery of the mysterious map. However, the plot feels incomplete as it ends right at the inciting incident. There's no resolution or even a hint of Elias's next steps.
#
# Here are a few suggestions:
#
# 1.  **Develop the "What's Next?":** The story stops just as the adventure is about to begin. Consider adding a paragraph or two that shows Elias making a decision about the map. Does he ignore it, or does he start preparing for a journey? This would provide a sense of forward momentum and a more satisfying conclusion to this snippet.
# 2.  **Show, Don't Just Tell, the Thrill:** While you mention Elias shivers with a thrill, you could enhance this by showing his physical reactions. Does his heart pound? Does a grin spread across his face? Showing these details would make his excitement more palpable for the reader.
# 3.  **Flesh out Elias's Character Slightly:** We learn he's a lighthouse keeper of fifty years, which suggests a life of routine. Hinting at his suppressed adventurous spirit (the "boy, dreaming of distant shores" line is good) could be expanded upon. Perhaps a brief thought about his life of isolation or a comparison between his current mundane existence and the promise of the map would add depth.
# RefinerAgent > Elias traced the salt-worn lines on the worn chart. It was a relic, tucked away in a forgotten sea chest, unlike any he’d seen in his fifty years tending the Porthaven light. This one, however, pulsed with an inner luminescence, faint emerald lines weaving a path across familiar seas, yet veering off into uncharted depths. He held it closer. The glow intensified, casting an eerie light on his weathered face. A single, pulsing X marked a spot far beyond the edge of any known land. Elias shivered, his heart thrumming a wild rhythm against his ribs, a sensation he hadn't felt since he was a boy, dreaming of distant shores. A wide, unbidden grin stretched across his face, crinkling the corners of his eyes. The map hummed, a silent promise of adventure, a stark contrast to the predictable rhythm of the waves and the solitary beam of his lighthouse. For fifty years, his life had been a solitary, ordered existence, a guardian of the known. But this map… this map whispered of the unknown, of a life less ordinary. He carefully refolded the chart, the strange glow seeming to imprint itself on his vision. Back in his spartan quarters, the familiar scent of brine and lamp oil did little to quell the burgeoning excitement. He looked out at the restless sea, no longer seeing just a vast expanse of water, but a canvas of possibilities. The routine of the lighthouse suddenly felt like a cage he hadn't realized he was in. The decision settled in his gut, firm and resolute. Tomorrow, he would begin gathering supplies. Tomorrow, Elias, the steadfast keeper of the Porthaven light, would set sail for the edges of the world.
# CriticAgent > APPROVED
# WARNING:google_genai.types:Warning: there are non-text parts in the response: ['function_call'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.

# %%
print("Congrats! You implemented a loop agent,creating a sophisticated system that can iteratively review and improve its own output.")
# Out:
# Congrats! You implemented a loop agent,creating a sophisticated system that can iteratively review and improve its own output.

# %% [markdown]
# ---
# ## Section 6: Summary - Choosing the Right Pattern
#
#
# <!--
# ```mermaid
# graph TD
#     A{"What kind of workflow do you need?"} -- > B["Fixed Pipeline<br>(A → B → C)"];
#     A -- > C["Concurrent Tasks<br>(Run A, B, C all at once)"];
#     A -- > D["Iterative Refinement<br>(A ⇆ B)"];
#     A -- > E["Dynamic Decisions<br>(Let the LLM decide what to do)"];
#
#     B -- > B_S["Use <b>SequentialAgent</b>"];
#     C -- > C_S["Use <b>ParallelAgent</b>"];
#     D -- > D_S["Use <b>LoopAgent</b>"];
#     E -- > E_S["Use <b>LLM Orchestrator</b><br>(Agent with other agents as tools)"];
#
#     style B_S fill:#f9f,stroke:#333,stroke-width:2px
#     style C_S fill:#ccf,stroke:#333,stroke-width:2px
#     style D_S fill:#cff,stroke:#333,stroke-width:2px
#     style E_S fill:#cfc,stroke:#333,stroke-width:2px
# ```
# -->

# %% [markdown]
# <img width="1000" src="https://storage.googleapis.com/github-repo/kaggle-5days-ai/day1/agent-decision-tree.png" alt="Agent Decision Tree" />
